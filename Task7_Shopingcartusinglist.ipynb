# %%
# Shopping Cart Using a Python List

# Initial cart list
cart = ["Laptop", "Mouse", "Keyboard", "Monitor", "Headphones"]

print("=== ORIGINAL CART ===")
print("Before:", cart)
print("Explanation: This is the starting list of products.\n")

# -----------------------------------------
# Display all products (already shown above)
# -----------------------------------------

print("All Products:", cart)
print("Explanation: Printing the entire list.\n")

# -----------------------------------------
# Access first and last products
# -----------------------------------------

print("First Product:", cart[0])
print("Explanation: cart[0] gives the first item.\n")

print("Last Product:", cart[-1])
print("Explanation: cart[-1] gives the last item.\n")

# -----------------------------------------
# Add "Webcam"
# -----------------------------------------

print("Before Adding Webcam:", cart)
cart.append("Webcam")
print("After Adding Webcam:", cart)
print("Explanation: append('Webcam') adds it to the end.\n")

# -----------------------------------------
# Insert "USB Hub" at index 2
# -----------------------------------------

print("Before Inserting USB Hub:", cart)
cart.insert(2, "USB Hub")
print("After Inserting USB Hub at index 2:", cart)
print("Explanation: insert(2, 'USB Hub') places it at position 2.\n")

# -----------------------------------------
# Remove "Mouse"
# -----------------------------------------

print("Before Removing Mouse:", cart)
cart.remove("Mouse")
print("After Removing Mouse:", cart)
print("Explanation: remove('Mouse') deletes the first matching item.\n")

# -----------------------------------------
# Remove last item using pop()
# -----------------------------------------

print("Before pop():", cart)
removed_item = cart.pop()
print("Removed Item:", removed_item)
print("After pop():", cart)
print("Explanation: pop() removes and returns the last item.\n")

# -----------------------------------------
# Find index of "Monitor"
# -----------------------------------------

monitor_index = cart.index("Monitor")
print("Index of Monitor:", monitor_index)
print("Explanation: index('Monitor') tells where Monitor is located.\n")

# -----------------------------------------
# Count occurrences of "Laptop"
# -----------------------------------------

laptop_count = cart.count("Laptop")
print("Laptop Count:", laptop_count)
print("Explanation: count('Laptop') shows how many times Laptop appears.\n")

# -----------------------------------------
# Create a copy of the cart
# -----------------------------------------

cart_copy = cart.copy()
print("Copied Cart:", cart_copy)
print("Explanation: copy() creates a separate duplicate list.\n")

# -----------------------------------------
# Reverse the cart
# -----------------------------------------

print("Before Reverse:", cart)
cart.reverse()
print("After Reverse:", cart)
print("Explanation: reverse() flips the list order.\n")

# -----------------------------------------
# Sort the products alphabetically
# -----------------------------------------

print("Before Sort:", cart)
cart.sort()
print("After Sort:", cart)
print("Explanation: sort() arranges items alphabetically.\n")
# Out:
# === ORIGINAL CART ===
# Before: ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Headphones']
# Explanation: This is the starting list of products.
#
# All Products: ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Headphones']
# Explanation: Printing the entire list.
#
# First Product: Laptop
# Explanation: cart[0] gives the first item.
#
# Last Product: Headphones
# Explanation: cart[-1] gives the last item.
#
# Before Adding Webcam: ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Headphones']
# After Adding Webcam: ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Headphones', 'Webcam']
# Explanation: append('Webcam') adds it to the end.
#
# Before Inserting USB Hub: ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Headphones', 'Webcam']
# After Inserting USB Hub at index 2: ['Laptop', 'Mouse', 'USB Hub', 'Keyboard', 'Monitor', 'Headphones', 'Webcam']
# Explanation: insert(2, 'USB Hub') places it at position 2.
#
# ...
